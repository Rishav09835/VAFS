# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional, Input

# %%
# Set to show plots inline
# %matplotlib inline

# %%
# Path to your folder with 20 CSVs
data_folder = r"C:\Users\hp\Desktop\VAFS-main\stockDATA"

# %%
output_folder = r"C:\Users\hp\Desktop\VAFS-main\lstm2pred"
os.makedirs(output_folder, exist_ok=True)

# %%
# Collect all CSV file names
company_files = [f for f in os.listdir(data_folder) if f.endswith('.csv')]

# %%
# Loop over each stock file
for filename in company_files:
    try:
        print(f"\n📂 Training on: {filename}")

        # Load and prepare data
        df = pd.read_csv(os.path.join(data_folder, filename))
        df['Date'] = pd.to_datetime(df['Date'])
        df.sort_values('Date', inplace=True)

        full_df = df.copy()  # to add prediction later

        # Use only 'Close' for LSTM
        close_data = df['Close'].values.reshape(-1, 1)
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_data = scaler.fit_transform(close_data)

        # Create sequences
        sequence_length = 60
        x, y = [], []
        for i in range(sequence_length, len(scaled_data)):
            x.append(scaled_data[i-sequence_length:i])
            y.append(scaled_data[i])
        x, y = np.array(x), np.array(y)

        # Train-test split
        split = int(len(x) * 0.8)
        x_train, x_test = x[:split], x[split:]
        y_train, y_test = y[:split], y[split:]

        # Build model
        model = Sequential()
        model.add(Bidirectional(LSTM(50, return_sequences=True), input_shape=(x_train.shape[1], 1)))
        model.add(Bidirectional(LSTM(50)))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        model.fit(x_train, y_train, epochs=10, batch_size=1, verbose=0)

        # Predict
        predictions = model.predict(x_test)
        predictions = scaler.inverse_transform(predictions)

        # Add prediction column to full DataFrame
        full_df['Prediction'] = np.nan
        full_df.iloc[-len(predictions):, full_df.columns.get_loc('Prediction')] = predictions.flatten()

        # Save result to output folder
        output_path = os.path.join(output_folder, filename.replace('.csv', '_with_prediction.csv'))
        full_df.to_csv(output_path, index=False)
        print(f"✅ Saved predictions to: {output_path}")

        # Optional: Plot
        plt.figure(figsize=(12, 6))
        plt.plot(df['Date'], df['Close'], label='Actual')
        plt.plot(df.iloc[-len(predictions):]['Date'], predictions, label='Predicted')
        plt.title(f'{filename} - Stock Price Prediction (Bidirectional LSTM)')
        plt.xlabel('Date')
        plt.ylabel('Stock Price')
        plt.legend()
        plt.grid(True)
        plt.show()

    except Exception as e:
        print(f"❌ Error processing {filename}: {e}")
# Out:
# 📂 Training on: ADANIPORTS.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\ADANIPORTS_with_prediction.csv
# 📂 Training on: ASIANPAINT.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\ASIANPAINT_with_prediction.csv
# 📂 Training on: AXISBANK.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\AXISBANK_with_prediction.csv
# 📂 Training on: BAJAJ-AUTO.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\BAJAJ-AUTO_with_prediction.csv
# 📂 Training on: BAJAJFINSV.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\BAJAJFINSV_with_prediction.csv
# 📂 Training on: BAJFINANCE.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\BAJFINANCE_with_prediction.csv
# 📂 Training on: BHARTIARTL.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\BHARTIARTL_with_prediction.csv
# 📂 Training on: BPCL.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\BPCL_with_prediction.csv
# 📂 Training on: BRITANNIA.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\BRITANNIA_with_prediction.csv
# 📂 Training on: CIPLA.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\CIPLA_with_prediction.csv
# 📂 Training on: COALINDIA.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\COALINDIA_with_prediction.csv
# 📂 Training on: DRREDDY.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\DRREDDY_with_prediction.csv
# 📂 Training on: EICHERMOT.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\EICHERMOT_with_prediction.csv
# 📂 Training on: GAIL.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\GAIL_with_prediction.csv
# 📂 Training on: GRASIM.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\GRASIM_with_prediction.csv
# 📂 Training on: HCLTECH.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\HCLTECH_with_prediction.csv
# 📂 Training on: HDFC.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\HDFC_with_prediction.csv
# 📂 Training on: HDFCBANK.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\HDFCBANK_with_prediction.csv
# 📂 Training on: HEROMOTOCO.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\HEROMOTOCO_with_prediction.csv
# 📂 Training on: HINDALCO.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\HINDALCO_with_prediction.csv
# 📂 Training on: HINDUNILVR.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\HINDUNILVR_with_prediction.csv
# 📂 Training on: ICICIBANK.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\ICICIBANK_with_prediction.csv
# 📂 Training on: INDUSINDBK.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\INDUSINDBK_with_prediction.csv
# 📂 Training on: INFRATEL.csv
# ❌ Error processing INFRATEL.csv: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required by MinMaxScaler.
#
# 📂 Training on: INFY.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\INFY_with_prediction.csv
# 📂 Training on: IOC.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\IOC_with_prediction.csv
# 📂 Training on: ITC.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\ITC_with_prediction.csv
# 📂 Training on: JSWSTEEL.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\JSWSTEEL_with_prediction.csv
# 📂 Training on: KOTAKBANK.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\KOTAKBANK_with_prediction.csv
# 📂 Training on: LT.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\LT_with_prediction.csv
# 📂 Training on: MARUTI.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\MARUTI_with_prediction.csv
# 📂 Training on: MM.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\MM_with_prediction.csv
# 📂 Training on: NESTLEIND.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\NESTLEIND_with_prediction.csv
# 📂 Training on: TCS.csv
# C:\Users\hp\anaconda\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# ✅ Saved predictions to: C:\Users\hp\Desktop\VAFS-main\lstm2pred\TCS_with_prediction.csv
